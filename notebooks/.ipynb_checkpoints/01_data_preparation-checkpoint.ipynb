# %% [markdown]
# # 1. Data Preparation – Tmin Peru Raster
#
# **Repositorio:** `Minimum-Temperature-Raster`
# **Objetivo:** Preparar los insumos base (raster y shapefile) para el análisis de temperaturas mínimas (Tmin) del Perú.
#
# ---
#
# ### Propósito
#
# 1. Cargar y limpiar los límites administrativos (departamentos, provincias o distritos).
# 2. Asegurar que los campos `NOMBRE`/`UBIGEO` estén **en mayúsculas** y **sin tildes**.
# 3. Cargar el raster GeoTIFF de **temperatura mínima (Tmin)** y verificar su estructura.
# 4. Preparar un bucle para iterar sobre las bandas (asumiendo Band 1 = año 2020, etc.).

# %% [markdown]
# **Importar librerías**

# %%
#En Anaconda Prompt
#pip install -r requirements.txt

# %%
import geopandas as gpd
import rasterio
import rioxarray  
import pandas as pd
import matplotlib.pyplot as plt
from unidecode import unidecode
from rasterio.plot import show

# %% [markdown]
# ## 1.1 Cargar shapefile de límites administrativos
#
# En este paso cargamos el shapefile del Perú (departamentos, provincias o distritos).
# Usamos rutas **relativas** (`data/raw/`) para asegurar reproducibilidad.
#
# Tenemos carpetas: district, province, department.

# %%
import os

# Mostrar el directorio de trabajo actual
print(os.getcwd())
# Out:
# /Users/freddyzutachavez/Documents/GitHub/Minimum-Temperature-Raster/notebooks

# %%
# Cambiar el directorio
os.chdir("/Users/freddyzutachavez/Documents/GitHub/Minimum-Temperature-Raster")

# %%
import geopandas as gpd
import os

# Definir rutas relativas
base_path = "data/raw"

# Rutas a cada nivel administrativo
shp_department = os.path.join(base_path, "department", "Departamental INEI 2023 geogpsperu SuyoPomalia.shp")
shp_province   = os.path.join(base_path, "province", "Provincial INEI 2023 geogpsperu SuyoPomalia.shp")
shp_district   = os.path.join(base_path, "district", "Distrital INEI 2023 geogpsperu SuyoPomalia.shp")

#Cargar shapefiles
dept = gpd.read_file(shp_department)
prov = gpd.read_file(shp_province)
dist = gpd.read_file(shp_district)

# %% [markdown]
# ## 1.2 Limpieza de campos: nombres y acentos
#
# Comprobamos que todos los nombres de columnas esten en mayúsculas y eliminamos los acentos o tildes de los nombres geográficos.
# Esto evita errores al hacer merges o zonal statistics.

# %% [markdown]
# **A.** Limpieza por departamento

# %%
# Mostrar una vista previa de las columnas clave
dept.head(3)
# Out:
#   CCDD DEPARTAMEN  OBJECTID  ESRI_OID  \
# 0   01   AMAZONAS       1.0       1.0
# 1   02     ANCASH       2.0       2.0
# 2   03   APURIMAC       3.0       3.0
#
#                                             geometry
# 0  POLYGON ((-77.81399 -2.99278, -77.81483 -2.995...
# 1  POLYGON ((-77.64697 -8.05086, -77.64689 -8.051...
# 2  POLYGON ((-73.74655 -13.17442, -73.7457 -13.17...

# %%
# Renombrar columnas a formato estándar en mayúsculas
dept = dept.rename(columns={
    'CDD': 'CCDD',
    'DEPARTAMEN': 'DEPARTAMENTO'})

# Eliminar columnas innecesarias
dept = dept.drop(columns=['OBJECTID', 'ESRI_OID'], errors='ignore')

# Asegurar tipo de dato correcto para el código (como string de 2 dígitos)
dept['CCDD'] = dept['CCDD'].astype(str).str.zfill(2)

# Normalizar nombres de departamento (en mayúsculas y sin espacios)
dept['DEPARTAMENTO'] = dept['DEPARTAMENTO'].str.strip().str.upper()

# Verificar resultado
dept.head(3)
# Out:
#   CCDD DEPARTAMENTO                                           geometry
# 0   01     AMAZONAS  POLYGON ((-77.81399 -2.99278, -77.81483 -2.995...
# 1   02       ANCASH  POLYGON ((-77.64697 -8.05086, -77.64689 -8.051...
# 2   03     APURIMAC  POLYGON ((-73.74655 -13.17442, -73.7457 -13.17...

# %% [markdown]
# **B.** Limpieza Provincia

# %%
# Mostrar una vista previa de las columnas clave
prov.head(3)
# Out:
#    OBJECTID CCDD CCPP DEPARTAMEN    PROVINCIA  \
# 0       1.0   01   01   AMAZONAS  CHACHAPOYAS
# 1       2.0   01   02   AMAZONAS        BAGUA
# 2       3.0   01   03   AMAZONAS      BONGARA
#
#                                             geometry
# 0  POLYGON ((-77.72614 -5.94354, -77.72486 -5.943...
# 1  POLYGON ((-78.61909 -4.51001, -78.61802 -4.510...
# 2  POLYGON ((-77.72759 -5.1403, -77.72361 -5.1406...

# %%
prov.columns
# Out:
# Index(['OBJECTID', 'CCDD', 'CCPP', 'DEPARTAMEN', 'PROVINCIA', 'GEOMETRY'], dtype='object')

# %%
from unidecode import unidecode

# Normalizar nombres de columnas
prov.columns = prov.columns.str.strip().str.upper()

# Asegurar consistencia en nombres de departamentos y provincias
prov['DEPARTAMEN'] = prov['DEPARTAMEN'].apply(lambda x: unidecode(x.strip().upper()))
prov['PROVINCIA'] = prov['PROVINCIA'].apply(lambda x: unidecode(x.strip().upper()))

# Eliminar columnas innecesarias
prov = prov.drop(columns=['OBJECTID'], errors='ignore')

# Eliminar posibles duplicados
prov = prov.drop_duplicates(subset=['CCDD', 'CCPP']).reset_index(drop=True)

# Verificar 
prov.head(5)
# Out:
#   CCDD CCPP DEPARTAMEN     PROVINCIA  \
# 0   01   01   AMAZONAS   CHACHAPOYAS
# 1   01   02   AMAZONAS         BAGUA
# 2   01   03   AMAZONAS       BONGARA
# 3   01   04   AMAZONAS  CONDORCANQUI
# 4   01   05   AMAZONAS          LUYA
#
#                                             GEOMETRY
# 0  POLYGON ((-77.72614 -5.94354, -77.72486 -5.943...
# 1  POLYGON ((-78.61909 -4.51001, -78.61802 -4.510...
# 2  POLYGON ((-77.72759 -5.1403, -77.72361 -5.1406...
# 3  POLYGON ((-77.81399 -2.99278, -77.81483 -2.995...
# 4  POLYGON ((-78.13023 -5.9037, -78.13011 -5.9041...

# %% [markdown]
# **C.** Limpieza distrito

# %%
# Mostrar una vista previa de las columnas clave
dist.head(3)
# Out:
#    UBIGEO CCDD CCPP CCDI DEPARTAMEN    PROVINCIA     DISTRITO  OBJECTID  \
# 0  010101   01   01   01   AMAZONAS  CHACHAPOYAS  CHACHAPOYAS       1.0
# 1  010102   01   01   02   AMAZONAS  CHACHAPOYAS     ASUNCION       2.0
# 2  010103   01   01   03   AMAZONAS  CHACHAPOYAS       BALSAS       3.0
#
#    ESRI_OID                                           GEOMETRY
# 0       1.0  POLYGON ((-77.8858 -6.1778, -77.88323 -6.17846...
# 1       2.0  POLYGON ((-77.74482 -5.94497, -77.74482 -5.945...
# 2       3.0  POLYGON ((-77.9358 -6.69039, -77.93531 -6.6909...

# %%
# Normalizar nombres de columnas
dist.columns = dist.columns.str.strip().str.upper()

# Asegurar consistencia en nombres
for col in ['DEPARTAMEN', 'PROVINCIA', 'DISTRITO']:
    dist[col] = dist[col].apply(lambda x: unidecode(x.strip().upper()))

dist.head(3)
# Out:
#    UBIGEO CCDD CCPP CCDI DEPARTAMEN    PROVINCIA     DISTRITO  OBJECTID  \
# 0  010101   01   01   01   AMAZONAS  CHACHAPOYAS  CHACHAPOYAS       1.0
# 1  010102   01   01   02   AMAZONAS  CHACHAPOYAS     ASUNCION       2.0
# 2  010103   01   01   03   AMAZONAS  CHACHAPOYAS       BALSAS       3.0
#
#    ESRI_OID                                           GEOMETRY
# 0       1.0  POLYGON ((-77.8858 -6.1778, -77.88323 -6.17846...
# 1       2.0  POLYGON ((-77.74482 -5.94497, -77.74482 -5.945...
# 2       3.0  POLYGON ((-77.9358 -6.69039, -77.93531 -6.6909...

# %% [markdown]
# ## 1.3. Verificar y ajustar el sistema de coordenadas (CRS)
#
# Todos los datos deben estar en el sistema de referencia **EPSG:4326 (WGS 84)**
# para que coincidan con el raster y sean compatibles con Streamlit Maps.

# %%
import geopandas as gpd

# Asegurar que GEOMETRY sea la geometría activa
dist = dist.set_geometry("GEOMETRY")

# Verificar CRS
print("CRS actual:", dist.crs)
# Out:
# CRS actual: EPSG:4326

# %%
Guardar shapefiles

# %%
# Guardar shapefiles reproyectados
dept.to_file("data/processed/departamentos.shp", driver="ESRI Shapefile", encoding="utf-8")
prov.to_file("data/processed/provincias.shp", driver="ESRI Shapefile", encoding="utf-8")
dist.to_file("data/processed/distritos.shp", driver="ESRI Shapefile", encoding="utf-8")

# %% [markdown]
# ## 1.5. Cargar y explorar el raster Tmin
#
# Abrimos el raster GeoTIFF (`tmin_raster.tif`), verificamos:
# - Número de bandas (puede representar años o meses)
# - CRS (debe ser el mismo que el shapefile)
# - Resolución espacial y extensión

# %%
# Cargar raster (ruta relativa desde notebooks/)
raster_path = "./data/raw/tmin_raster.tif"

raster = rasterio.open(raster_path)

print("Raster cargado correctamente")
print(f"Bandas: {raster.count}")
print(f"CRS: {raster.crs}")
print(f"Resolución: {raster.res}")
print(f"Límites: {raster.bounds}")
# Out:
# Raster cargado correctamente
# Bandas: 5
# CRS: EPSG:4326
# Resolución: (0.04999999999999716, 0.050000000000000044)
# Límites: BoundingBox(left=-81.38, bottom=-18.65000000000002, right=-67.1300000000008, top=1.2000000000000002)

# %%
# Visualizar una banda (por ejemplo, la primera)
import matplotlib.pyplot as plt
from rasterio.plot import show

fig, ax = plt.subplots(figsize=(6, 6))
show(raster, 1, ax=ax, cmap="coolwarm")
ax.set_title("Temperatura mínima - Banda 1")
plt.show()

# Información de todas las bandas
for i in range(1, raster.count + 1):
    band = raster.read(i)
    print(f"Banda {i}: min={band.min():.2f}, max={band.max():.2f}, mean={band.mean():.2f}")
# Out:
# Banda 1: min=nan, max=nan, mean=nan
# Banda 2: min=nan, max=nan, mean=nan
# Banda 3: min=nan, max=nan, mean=nan
# Banda 4: min=nan, max=nan, mean=nan
# Banda 5: min=nan, max=nan, mean=nan

# %% [markdown]
# **Cargar el raster con rioxarray y asignar nombres a las bandas (2020–2024)**

# %%
import rioxarray

# Cargar el raster con rioxarray (mantiene metadatos geoespaciales)
tmin = rioxarray.open_rasterio("./data/raw/tmin_raster.tif", masked=True)

# Revisar la estructura del objeto
print(tmin)

# Asignar nombres de banda según los años
años = [2020, 2021, 2022, 2023, 2024]
tmin = tmin.assign_coords(band=años)

print("\n Bandas renombradas:")
print(tmin.band.values)
# Out:
# <xarray.DataArray (band: 5, y: 397, x: 285)> Size: 2MB
# [565725 values with dtype=float32]
# Coordinates:
#   * band         (band) int64 40B 1 2 3 4 5
#   * y            (y) float64 3kB 1.175 1.125 1.075 ... -18.53 -18.58 -18.63
#   * x            (x) float64 2kB -81.35 -81.3 -81.25 ... -67.26 -67.21 -67.16
#     spatial_ref  int64 8B 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#
#  Bandas renombradas:
# [2020 2021 2022 2023 2024]

# %%
# Ver un resumen estadístico general
print("\n Estadísticas descriptivas por año:")
for año in tmin.band.values:
    datos = tmin.sel(band=año)
    print(f"Año {año}: min={float(datos.min()):.2f}, max={float(datos.max()):.2f}, mean={float(datos.mean()):.2f}")
# Out:
#  Estadísticas descriptivas por año:
# Año 2020: min=-9.05, max=24.64, mean=18.01
# Año 2021: min=-10.02, max=24.39, mean=17.91
# Año 2022: min=-9.87, max=24.21, mean=17.77
# Año 2023: min=-9.06, max=24.12, mean=17.61
# Año 2024: min=-8.85, max=24.15, mean=17.82

# %% [markdown]
# ## fase de zonal statistics

# %%
dist
# Out:
#       UBIGEO CCDD CCPP CCDI DEPARTAMEN    PROVINCIA                DISTRITO  \
# 0     010101   01   01   01   AMAZONAS  CHACHAPOYAS             CHACHAPOYAS
# 1     010102   01   01   02   AMAZONAS  CHACHAPOYAS                ASUNCION
# 2     010103   01   01   03   AMAZONAS  CHACHAPOYAS                  BALSAS
# 3     010104   01   01   04   AMAZONAS  CHACHAPOYAS                   CHETO
# 4     010105   01   01   05   AMAZONAS  CHACHAPOYAS               CHILIQUIN
# ...      ...  ...  ...  ...        ...          ...                     ...
# 1886  250304   25   03   04    UCAYALI   PADRE ABAD                 NESHUYA
# 1887  250305   25   03   05    UCAYALI   PADRE ABAD  ALEXANDER VON HUMBOLDT
# 1888  250306   25   03   06    UCAYALI   PADRE ABAD                 HUIPOCA
# 1889  250307   25   03   07    UCAYALI   PADRE ABAD                BOQUERON
# 1890  250401   25   04   01    UCAYALI        PURUS                   PURUS
#
#       OBJECTID  ESRI_OID                                           GEOMETRY
# 0          1.0       1.0  POLYGON ((-77.8858 -6.1778, -77.88323 -6.17846...
# 1          2.0       2.0  POLYGON ((-77.74482 -5.94497, -77.74482 -5.945...
# 2          3.0       3.0  POLYGON ((-77.9358 -6.69039, -77.93531 -6.6909...
# 3          4.0       4.0  POLYGON ((-77.71486 -6.24598, -77.71485 -6.245...
# 4          5.0       5.0  POLYGON ((-77.77405 -5.99598, -77.77328 -5.996...
# ...        ...       ...                                                ...
# 1886    1887.0    1887.0  POLYGON ((-75.01663 -8.44514, -75.0165 -8.4453...
# 1887    1888.0    1888.0  POLYGON ((-75.02136 -8.73948, -75.02136 -8.739...
# 1888    1889.0    1889.0  POLYGON ((-75.3844 -8.58229, -75.38423 -8.5825...
# 1889    1890.0    1890.0  POLYGON ((-75.77583 -8.91013, -75.77427 -8.910...
# 1890    1891.0    1891.0  POLYGON ((-70.50641 -9.42392, -70.50643 -9.424...
#
# [1891 rows x 10 columns]

# %%
import rioxarray
import geopandas as gpd
import os

# 1️⃣ Aseguramos que ambos (raster y shapefile) estén en el mismo CRS
if dist.crs != tmin.rio.crs:
    dist = dist.to_crs(tmin.rio.crs)
    print("Shapefile reproyectado al CRS del raster:", dist.crs)
    
# 2️⃣ Creamos un polígono único de todo el país (para eficiencia)
peru = dist[['GEOMETRY']].dissolve()
print("✅ Geometría de Perú generada")

# 3️⃣ Recorte del raster (todas las bandas)
tmin_dist = tmin.rio.clip(peru.geometry, peru.crs, drop=True)

# 5️⃣ Guardar resultado
tmin_dist_path = "data/processed/tmin_dist_clip.tif"
tmin_dist.rio.to_raster(tmin_dist_path)

print(f"✅ Raster recortado guardado en: {tmin_dist_path}")
print("Dimensiones:", tmin_dist.shape)
print("Bandas:", list(tmin_dist.band.values))
print("CRS:", tmin_dist.rio.crs)
# Out:
# ✅ Geometría de Perú generada
# ✅ Raster recortado guardado en: data/processed/tmin_dist_clip.tif
# Dimensiones: (5, 366, 253)
# Bandas: [np.int64(2020), np.int64(2021), np.int64(2022), np.int64(2023), np.int64(2024)]
# CRS: EPSG:4326

# %%
dist
# Out:
#       UBIGEO CCDD CCPP CCDI DEPARTAMEN    PROVINCIA                DISTRITO  \
# 0     010101   01   01   01   AMAZONAS  CHACHAPOYAS             CHACHAPOYAS
# 1     010102   01   01   02   AMAZONAS  CHACHAPOYAS                ASUNCION
# 2     010103   01   01   03   AMAZONAS  CHACHAPOYAS                  BALSAS
# 3     010104   01   01   04   AMAZONAS  CHACHAPOYAS                   CHETO
# 4     010105   01   01   05   AMAZONAS  CHACHAPOYAS               CHILIQUIN
# ...      ...  ...  ...  ...        ...          ...                     ...
# 1886  250304   25   03   04    UCAYALI   PADRE ABAD                 NESHUYA
# 1887  250305   25   03   05    UCAYALI   PADRE ABAD  ALEXANDER VON HUMBOLDT
# 1888  250306   25   03   06    UCAYALI   PADRE ABAD                 HUIPOCA
# 1889  250307   25   03   07    UCAYALI   PADRE ABAD                BOQUERON
# 1890  250401   25   04   01    UCAYALI        PURUS                   PURUS
#
#       OBJECTID  ESRI_OID                                           GEOMETRY
# 0          1.0       1.0  POLYGON ((-77.8858 -6.1778, -77.88323 -6.17846...
# 1          2.0       2.0  POLYGON ((-77.74482 -5.94497, -77.74482 -5.945...
# 2          3.0       3.0  POLYGON ((-77.9358 -6.69039, -77.93531 -6.6909...
# 3          4.0       4.0  POLYGON ((-77.71486 -6.24598, -77.71485 -6.245...
# 4          5.0       5.0  POLYGON ((-77.77405 -5.99598, -77.77328 -5.996...
# ...        ...       ...                                                ...
# 1886    1887.0    1887.0  POLYGON ((-75.01663 -8.44514, -75.0165 -8.4453...
# 1887    1888.0    1888.0  POLYGON ((-75.02136 -8.73948, -75.02136 -8.739...
# 1888    1889.0    1889.0  POLYGON ((-75.3844 -8.58229, -75.38423 -8.5825...
# 1889    1890.0    1890.0  POLYGON ((-75.77583 -8.91013, -75.77427 -8.910...
# 1890    1891.0    1891.0  POLYGON ((-70.50641 -9.42392, -70.50643 -9.424...
#
# [1891 rows x 10 columns]

# %% [markdown]
# ## estadisticos

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import rioxarray
from rasterstats import zonal_stats
import matplotlib.pyplot as plt
from pathlib import Path

# Opcional: rutas por si quieres reabrir desde disco
# tmin = rioxarray.open_rasterio("data/processed/tmin_dist_clip.tif", masked=True)
# dist = gpd.read_file("data/processed/distritos.shp")

# Alinear CRS entre polígonos y raster (muy importante)
if dist.crs != tmin.rio.crs:
    dist_proj = dist.to_crs(tmin.rio.crs)
else:
    dist_proj = dist

# Garantizar UBIGEO (útil para unir y exportar)
if "UBIGEO" not in dist_proj.columns:
    dist_proj["UBIGEO"] = (
        dist_proj["CCDD"].astype(str).str.zfill(2)
        + dist_proj["CCPP"].astype(str).str.zfill(2)
        + dist_proj["CCDI"].astype(str).str.zfill(2)
    )

# Parámetros raster
affine = tmin.rio.transform()
nodata  = tmin.rio.nodata
if nodata is None:
    nodata = -9999  # define un NODATA explícito si el raster no lo tiene

# Eje temporal / bandas (p.ej. [2020, 2021, 2022, 2023, 2024])
periodos = tmin.coords["band"].values
periodos
# Out:
# array([2020, 2021, 2022, 2023, 2024])

# %%
# 3) Helper para limpiar el array que llega a add_stats (evita "read-only" y respeta máscara)
def _vals_clean(x):
    """
    x puede ser ndarray o MaskedArray. Devuelve un vector 1D float,
    copia (writable), sin máscara y sin NaN/Inf.
    """
    mx = np.ma.asarray(x)                     # garantiza masked array
    data = mx.compressed()                    # aplica máscara -> 1D ndarray
    data = np.array(data, dtype=float, copy=True)  # fuerza copia writable
    if data.size == 0:
        return data
    good = np.isfinite(data)                  # filtra NaN/Inf
    return data[good]

# %%
# 4) Métricas
base_stats = ["count", "mean", "min", "max", "std"]
add_stats = {
    "p10":      lambda x: np.nan if _vals_clean(x).size == 0 else np.nanpercentile(_vals_clean(x), 10),
    "p90":      lambda x: np.nan if _vals_clean(x).size == 0 else np.nanpercentile(_vals_clean(x), 90),
    "iqr":      lambda x: np.nan if _vals_clean(x).size == 0 else (np.nanpercentile(_vals_clean(x), 75) - np.nanpercentile(_vals_clean(x), 25)),
    "amplitud": lambda x: np.nan if _vals_clean(x).size == 0 else (np.nanmax(_vals_clean(x)) - np.nanmin(_vals_clean(x))),
}

# %%
# 5) Tabla de atributos distritales para adjuntar a las métricas
#    (ajustado a tus nombres de columnas reales)
attrs_cols = ["UBIGEO", "CCDD", "CCPP", "CCDI", "DEPARTAMEN", "PROVINCIA", "DISTRITO"]
attrs_cols = [c for c in attrs_cols if c in dist_proj.columns]  # por seguridad
attrs = dist_proj[attrs_cols].reset_index(drop=True)

# %%
# 6) Loop por bandas/periodos y cálculo de zonales
resultados = []
for p in periodos:
    # Extrae la banda como matriz 2D (y, x)
    arr = tmin.sel(band=p).values

    # Cálculo de estadísticas zonales
    zs = zonal_stats(
        dist_proj,          # geometrías (distritos)
        arr,                # raster 2D
        affine=affine,
        nodata=nodata,
        stats=base_stats,
        add_stats=add_stats,
        all_touched=False   # True para incluir celdas tocadas en borde
    )

    df = pd.DataFrame(zs)
    df.insert(0, "periodo", p)
    out = pd.concat([attrs.copy(), df], axis=1)
    resultados.append(out)

# %%
# 7) Unir todo y renombrar columnas a etiquetas claras
zonal_distritos = pd.concat(resultados, ignore_index=True)
zonal_distritos = zonal_distritos.rename(columns={
    "mean": "tmin_mean",
    "min": "tmin_min",
    "max": "tmin_max",
    "std": "tmin_std",
    "count": "pix_count",
    "p10": "tmin_p10",
    "p90": "tmin_p90",
    "iqr": "tmin_iqr",
    "amplitud": "tmin_amplitud",
})

# %%
zonal_distritos.head(5)
# Out:
#    UBIGEO CCDD CCPP CCDI DEPARTAMEN    PROVINCIA     DISTRITO  periodo  \
# 0  010101   01   01   01   AMAZONAS  CHACHAPOYAS  CHACHAPOYAS     2020
# 1  010102   01   01   02   AMAZONAS  CHACHAPOYAS     ASUNCION     2020
# 2  010103   01   01   03   AMAZONAS  CHACHAPOYAS       BALSAS     2020
# 3  010104   01   01   04   AMAZONAS  CHACHAPOYAS        CHETO     2020
# 4  010105   01   01   05   AMAZONAS  CHACHAPOYAS    CHILIQUIN     2020
#
#     tmin_min   tmin_max  tmin_mean  pix_count  tmin_std   tmin_p10   tmin_p90  \
# 0  11.155586  13.316497  12.559916          6  0.763999  11.549891  13.223657
# 1  10.110104  10.539493  10.324799          2  0.214694  10.153043  10.496554
# 2   9.299319  19.025255  14.643280         11  3.246553  10.763714  18.204876
# 3  11.776923  12.021763  11.928758          3  0.108266  11.819056  12.014928
# 4   9.482246  12.857030  11.165710          5  1.144948   9.932108  12.468654
#
#    tmin_iqr  tmin_amplitud
# 0  0.929875       2.160911
# 1  0.214694       0.429389
# 2  5.930583       9.725936
# 3  0.122420       0.244840
# 4  1.279191       3.374784

# %%
# 9) Validaciones rápidas
# 9.1 Histograma de Tmin media para un año de referencia
anio_plot = periodos[0]  # cambia a un año específico si quieres
tmp = zonal_distritos[zonal_distritos["periodo"] == anio_plot]["tmin_mean"].dropna()

plt.figure(figsize=(6, 4))
plt.hist(tmp, bins=40)
plt.title(f"Distribución de Tmin media distrital – {anio_plot}")
plt.xlabel("Tmin media (°C)")
plt.ylabel("Frecuencia")
plt.tight_layout()
plt.show()

# %%
# 9.2 Conteo de nulos por año
nulls_por_anio = (
    zonal_distritos
    .groupby("periodo")["tmin_mean"]
    .apply(lambda s: s.isna().sum())
    .rename("n_nulls")
    .reset_index()
)
print(nulls_por_anio)
# Out:
#    periodo  n_nulls
# 0     2020       86
# 1     2021       86
# 2     2022       86
# 3     2023       86
# 4     2024       86

# %%
# 9.3 Boxplot de temeperatura minima por año 
plt.figure(figsize=(8, 5))
zonal_distritos.boxplot(
    column="tmin_mean", by="periodo",
    patch_artist=True,
    boxprops=dict(facecolor="#88ccee", color="#336699"),
    medianprops=dict(color="red", linewidth=2),
    whiskerprops=dict(color="#336699"),
    capprops=dict(color="#336699"),
    flierprops=dict(marker='o', markersize=3, alpha=0.5, color="#336699")
)
plt.title("Distribución de la temperatura mínima media por año", fontsize=13, weight="bold")
plt.suptitle("")
plt.xlabel("Año", fontsize=11)
plt.ylabel("Temperatura mínima media (°C)", fontsize=11)
plt.grid(alpha=0.3, linestyle="--")
plt.tight_layout()
plt.show()

# %%
dist
# Out:
#       UBIGEO CCDD CCPP CCDI DEPARTAMEN    PROVINCIA                DISTRITO  \
# 0     010101   01   01   01   AMAZONAS  CHACHAPOYAS             CHACHAPOYAS
# 1     010102   01   01   02   AMAZONAS  CHACHAPOYAS                ASUNCION
# 2     010103   01   01   03   AMAZONAS  CHACHAPOYAS                  BALSAS
# 3     010104   01   01   04   AMAZONAS  CHACHAPOYAS                   CHETO
# 4     010105   01   01   05   AMAZONAS  CHACHAPOYAS               CHILIQUIN
# ...      ...  ...  ...  ...        ...          ...                     ...
# 1886  250304   25   03   04    UCAYALI   PADRE ABAD                 NESHUYA
# 1887  250305   25   03   05    UCAYALI   PADRE ABAD  ALEXANDER VON HUMBOLDT
# 1888  250306   25   03   06    UCAYALI   PADRE ABAD                 HUIPOCA
# 1889  250307   25   03   07    UCAYALI   PADRE ABAD                BOQUERON
# 1890  250401   25   04   01    UCAYALI        PURUS                   PURUS
#
#       OBJECTID  ESRI_OID                                           GEOMETRY
# 0          1.0       1.0  POLYGON ((-77.8858 -6.1778, -77.88323 -6.17846...
# 1          2.0       2.0  POLYGON ((-77.74482 -5.94497, -77.74482 -5.945...
# 2          3.0       3.0  POLYGON ((-77.9358 -6.69039, -77.93531 -6.6909...
# 3          4.0       4.0  POLYGON ((-77.71486 -6.24598, -77.71485 -6.245...
# 4          5.0       5.0  POLYGON ((-77.77405 -5.99598, -77.77328 -5.996...
# ...        ...       ...                                                ...
# 1886    1887.0    1887.0  POLYGON ((-75.01663 -8.44514, -75.0165 -8.4453...
# 1887    1888.0    1888.0  POLYGON ((-75.02136 -8.73948, -75.02136 -8.739...
# 1888    1889.0    1889.0  POLYGON ((-75.3844 -8.58229, -75.38423 -8.5825...
# 1889    1890.0    1890.0  POLYGON ((-75.77583 -8.91013, -75.77427 -8.910...
# 1890    1891.0    1891.0  POLYGON ((-70.50641 -9.42392, -70.50643 -9.424...
#
# [1891 rows x 10 columns]

# %% [markdown]
# #Importamos shapefile procesado

# %%
import geopandas as gpd
from rasterstats import zonal_stats
import pandas as pd
from shapely.geometry import box
import numpy as np
import pandas as pd


# Ruta a shapefile procesado
shp_path = "./data/processed/distritos.shp"

# Cargar shapefile
dist = gpd.read_file(shp_path)

# %%
# --- helpers seguros ---
def _vals_clean(x):
    mx = np.ma.asarray(x)
    v  = mx.compressed()                      # quita máscara -> 1D
    if v.size == 0:
        return np.array([], dtype=float)
    v = np.array(v, dtype=float, copy=True)   # copia = writable
    v = v[np.isfinite(v)]                     # sin NaN/Inf
    return v

def p10_safe(x):
    v = _vals_clean(x)
    return np.nan if v.size == 0 else np.nanpercentile(v, 10)

def p90_safe(x):
    v = _vals_clean(x)
    return np.nan if v.size == 0 else np.nanpercentile(v, 90)

def amplitud_safe(x):
    v = _vals_clean(x)
    return np.nan if v.size == 0 else (np.nanmax(v) - np.nanmin(v))

# --- (opcional) filtra distritos que caen dentro del extent del raster ---
# si ya tienes `tmin` (rioxarray) cargado:
# if dist.crs != tmin.rio.crs:
#     dist_in = dist.to_crs(tmin.rio.crs)
# else:
#     dist_in = dist.copy()
# bbox = box(*tmin.rio.bounds())
# dist_in = dist_in[dist_in.intersects(bbox)].copy()
# si no, usa todo dist:
dist_in = dist

anios_dist = [2020, 2021, 2022, 2023, 2024]
estadisticos_dist = ["count", "mean", "min", "max", "std", "median",
                     "percentile_10", "percentile_90", "amplitud"]
acum_dist = {stat: [] for stat in estadisticos_dist}

for año in anios_dist:
    stats_dist = zonal_stats(
        dist_in,
        "./data/raw/tmin_raster.tif",
        stats=["count", "mean", "min", "max", "std", "median"],
        add_stats={
            "percentile_10": p10_safe,
            "percentile_90": p90_safe,
            "amplitud":      amplitud_safe,
        },
        band=(año - 2019),
        geojson_out=False,
        nodata=None,          # si tu TIFF tiene NODATA, ponlo aquí (ej. -9999)
        all_touched=False
    )
    df_dist = pd.DataFrame(stats_dist)
    for stat in estadisticos_dist:
        if stat in df_dist.columns:
            acum_dist[stat].append(df_dist[stat].to_numpy())

# promedios 2020–2024 por estadístico; se agregan a dist_in
for stat, listas in acum_dist.items():
    if len(listas) == len(anios_dist) and len(listas) > 0:
        arr = np.vstack(listas)                 # (5, n_distritos_validos)
        dist_in[f"tmin_{stat}_total"] = np.nanmean(arr, axis=0)

# vuelca a 'dist' (alineación por índice; donde no intersecta queda NaN)
for col in dist_in.columns:
    if col.startswith("tmin_") and col.endswith("_total"):
        dist[col] = dist_in[col]

cols_totales_dist = [c for c in dist.columns if c.startswith("tmin_") and c.endswith("_total")]
print("Columnas totales creadas:", cols_totales_dist)
print(dist[["DISTRITO"] + cols_totales_dist].head())
# Out:
# Columnas totales creadas: ['tmin_count_total', 'tmin_mean_total', 'tmin_min_total', 'tmin_max_total', 'tmin_std_total', 'tmin_median_total', 'tmin_percentile_10_total', 'tmin_percentile_90_total', 'tmin_amplitud_total']
#       DISTRITO  tmin_count_total  tmin_mean_total  tmin_min_total  \
# 0  CHACHAPOYAS               6.0        12.403868       11.032648
# 1     ASUNCION               2.0        10.232676       10.029134
# 2       BALSAS              11.0        14.492733        9.164226
# 3        CHETO               3.0        11.770264       11.627967
# 4    CHILIQUIN               5.0        11.065167        9.423780
#
#    tmin_max_total  tmin_std_total  tmin_median_total  \
# 0       13.120787        0.744316          12.742976
# 1       10.436218        0.203542          10.232676
# 2       18.931234        3.263794          15.668368
# 3       11.850517        0.100983          11.832309
# 4       12.711129        1.117485          10.918611
#
#    tmin_percentile_10_total  tmin_percentile_90_total  tmin_amplitud_total
# 0                 11.418373                 13.050255             2.088139
# 1                 10.069842                 10.395510             0.407085
# 2                 10.584344                 18.079209             9.767008
# 3                 11.668836                 11.846875             0.222549
# 4                  9.854567                 12.335305             3.287350
# /var/folders/cx/g5gs5tnx3m3bprnnzxq291_40000gn/T/ipykernel_6786/2549981370.py:63: RuntimeWarning: Mean of empty slice
#   dist_in[f"tmin_{stat}_total"] = np.nanmean(arr, axis=0)
# /var/folders/cx/g5gs5tnx3m3bprnnzxq291_40000gn/T/ipykernel_6786/2549981370.py:63: RuntimeWarning: Mean of empty slice
#   dist_in[f"tmin_{stat}_total"] = np.nanmean(arr, axis=0)
# /var/folders/cx/g5gs5tnx3m3bprnnzxq291_40000gn/T/ipykernel_6786/2549981370.py:63: RuntimeWarning: Mean of empty slice
#   dist_in[f"tmin_{stat}_total"] = np.nanmean(arr, axis=0)
# /var/folders/cx/g5gs5tnx3m3bprnnzxq291_40000gn/T/ipykernel_6786/2549981370.py:63: RuntimeWarning: Mean of empty slice
#   dist_in[f"tmin_{stat}_total"] = np.nanmean(arr, axis=0)
# /var/folders/cx/g5gs5tnx3m3bprnnzxq291_40000gn/T/ipykernel_6786/2549981370.py:63: RuntimeWarning: Mean of empty slice
#   dist_in[f"tmin_{stat}_total"] = np.nanmean(arr, axis=0)
# /var/folders/cx/g5gs5tnx3m3bprnnzxq291_40000gn/T/ipykernel_6786/2549981370.py:63: RuntimeWarning: Mean of empty slice
#   dist_in[f"tmin_{stat}_total"] = np.nanmean(arr, axis=0)
# /var/folders/cx/g5gs5tnx3m3bprnnzxq291_40000gn/T/ipykernel_6786/2549981370.py:63: RuntimeWarning: Mean of empty slice
#   dist_in[f"tmin_{stat}_total"] = np.nanmean(arr, axis=0)
# /var/folders/cx/g5gs5tnx3m3bprnnzxq291_40000gn/T/ipykernel_6786/2549981370.py:63: RuntimeWarning: Mean of empty slice
#   dist_in[f"tmin_{stat}_total"] = np.nanmean(arr, axis=0)

# %%
dist
# Out:
#       UBIGEO CCDD CCPP CCDI DEPARTAMEN    PROVINCIA                DISTRITO  \
# 0     010101   01   01   01   AMAZONAS  CHACHAPOYAS             CHACHAPOYAS
# 1     010102   01   01   02   AMAZONAS  CHACHAPOYAS                ASUNCION
# 2     010103   01   01   03   AMAZONAS  CHACHAPOYAS                  BALSAS
# 3     010104   01   01   04   AMAZONAS  CHACHAPOYAS                   CHETO
# 4     010105   01   01   05   AMAZONAS  CHACHAPOYAS               CHILIQUIN
# ...      ...  ...  ...  ...        ...          ...                     ...
# 1886  250304   25   03   04    UCAYALI   PADRE ABAD                 NESHUYA
# 1887  250305   25   03   05    UCAYALI   PADRE ABAD  ALEXANDER VON HUMBOLDT
# 1888  250306   25   03   06    UCAYALI   PADRE ABAD                 HUIPOCA
# 1889  250307   25   03   07    UCAYALI   PADRE ABAD                BOQUERON
# 1890  250401   25   04   01    UCAYALI        PURUS                   PURUS
#
#       OBJECTID  ESRI_OID                                           geometry  \
# 0          1.0       1.0  POLYGON ((-77.8858 -6.1778, -77.88323 -6.17846...
# 1          2.0       2.0  POLYGON ((-77.74482 -5.94497, -77.74482 -5.945...
# 2          3.0       3.0  POLYGON ((-77.9358 -6.69039, -77.93531 -6.6909...
# 3          4.0       4.0  POLYGON ((-77.71486 -6.24598, -77.71485 -6.245...
# 4          5.0       5.0  POLYGON ((-77.77405 -5.99598, -77.77328 -5.996...
# ...        ...       ...                                                ...
# 1886    1887.0    1887.0  POLYGON ((-75.01663 -8.44514, -75.0165 -8.4453...
# 1887    1888.0    1888.0  POLYGON ((-75.02136 -8.73948, -75.02136 -8.739...
# 1888    1889.0    1889.0  POLYGON ((-75.3844 -8.58229, -75.38423 -8.5825...
# 1889    1890.0    1890.0  POLYGON ((-75.77583 -8.91013, -75.77427 -8.910...
# 1890    1891.0    1891.0  POLYGON ((-70.50641 -9.42392, -70.50643 -9.424...
#
#       tmin_count_total  tmin_mean_total  tmin_min_total  tmin_max_total  \
# 0                  6.0        12.403868       11.032648       13.120787
# 1                  2.0        10.232676       10.029134       10.436218
# 2                 11.0        14.492733        9.164226       18.931234
# 3                  3.0        11.770264       11.627967       11.850517
# 4                  5.0        11.065167        9.423780       12.711129
# ...                ...              ...             ...             ...
# 1886              22.0        21.937903       21.727421       22.180375
# 1887               6.0        21.862907       21.730026       21.946946
# 1888              18.0        22.090904       21.916062       22.266233
# 1889              19.0        17.905087       14.919734       21.548261
# 1890             610.0        21.863619       21.466217       22.127753
#
#       tmin_std_total  tmin_median_total  tmin_percentile_10_total  \
# 0           0.744316          12.742976                 11.418373
# 1           0.203542          10.232676                 10.069842
# 2           3.263794          15.668368                 10.584344
# 3           0.100983          11.832309                 11.668836
# 4           1.117485          10.918611                  9.854567
# ...              ...                ...                       ...
# 1886        0.133436          21.905812                 21.771170
# 1887        0.080880          21.892983                 21.756207
# 1888        0.090198          22.106946                 21.978192
# 1889        1.710479          17.815664                 15.770541
# 1890        0.137997          21.874852                 21.669309
#
#       tmin_percentile_90_total  tmin_amplitud_total
# 0                    13.050255             2.088139
# 1                    10.395510             0.407085
# 2                    18.079209             9.767008
# 3                    11.846875             0.222549
# 4                    12.335305             3.287350
# ...                        ...                  ...
# 1886                 22.140653             0.452954
# 1887                 21.939533             0.216920
# 1888                 22.179917             0.350171
# 1889                 19.830037             6.628527
# 1890                 22.026529             0.661536
#
# [1891 rows x 19 columns]

# %%
# Visualizar los resultados en un mapa
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

colors = ["#b3b3b3", "#1f77b4", "#ffa500"]  # gris → azul → anaranjado
cmap_custom = LinearSegmentedColormap.from_list("FrioAzulNaranja", colors, N=256)

# 🗺️ Graficar el mapa
fig, ax = plt.subplots(1, 1, figsize=(12, 10))
dist.plot(
    column="tmin_mean_total",
    ax=ax,
    legend=True,
    cmap=cmap_custom,
    legend_kwds={
        'label': "Temperatura mínima promedio (°C)",
        'orientation': 'vertical'
    }
)
ax.set_title("Temperatura mínima promedio por distrito", fontsize=14, fontweight="bold")
ax.axis("off")
plt.show()

print("\nColumnas disponibles en el dataframe:")
print(dist.columns.tolist())
# Out:
# Columnas disponibles en el dataframe:
# ['UBIGEO', 'CCDD', 'CCPP', 'CCDI', 'DEPARTAMEN', 'PROVINCIA', 'DISTRITO', 'OBJECTID', 'ESRI_OID', 'geometry', 'tmin_count_total', 'tmin_mean_total', 'tmin_min_total', 'tmin_max_total', 'tmin_std_total', 'tmin_median_total', 'tmin_percentile_10_total', 'tmin_percentile_90_total', 'tmin_amplitud_total']

# %%
# Histogramas
for col in stats_cols:
    plt.figure(figsize=(7,4))
    dist[col].hist(bins=30)
    plt.title(f"Histograma: {col}")
    plt.xlabel(col)
    plt.ylabel("Frecuencia")
    plt.grid(alpha=0.2)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[153], line 2
#       1 # Histogramas
# ----> 2 for col in stats_cols:
#       3     plt.figure(figsize=(7,4))
#       4     dist[col].hist(bins=30)
#
# NameError: name 'stats_cols' is not defined

# %% [markdown]
# ## Otra opcion: estaditicos por regiones

# %% [markdown]
# Próximo paso: unir raster + shapefiles
#
# Como el raster ya está en rioxarray, se puede calcular estadísticas directamente sobre cada polígono (departamento, provincia o distrito).

# %% [markdown]
# Te dejo ejemplo de GTP sin revisar, si te ayuda

# %%
dept
# Out:
#    CCDD     DEPARTAMEN  OBJECTID  ESRI_OID  \
# 0    01       AMAZONAS       1.0       1.0
# 1    02         ANCASH       2.0       2.0
# 2    03       APURIMAC       3.0       3.0
# 3    04       AREQUIPA       4.0       4.0
# 4    05       AYACUCHO       5.0       5.0
# 5    06      CAJAMARCA       6.0       6.0
# 6    07         CALLAO       7.0       7.0
# 7    08          CUSCO       8.0       8.0
# 8    09   HUANCAVELICA       9.0       9.0
# 9    10        HUANUCO      10.0      10.0
# 10   11            ICA      11.0      11.0
# 11   12          JUNIN      12.0      12.0
# 12   13    LA LIBERTAD      13.0      13.0
# 13   14     LAMBAYEQUE      14.0      14.0
# 14   15           LIMA      15.0      15.0
# 15   16         LORETO      16.0      16.0
# 16   17  MADRE DE DIOS      17.0      17.0
# 17   18       MOQUEGUA      18.0      18.0
# 18   19          PASCO      19.0      19.0
# 19   20          PIURA      20.0      20.0
# 20   21           PUNO      21.0      21.0
# 21   22     SAN MARTIN      22.0      22.0
# 22   23          TACNA      23.0      23.0
# 23   24         TUMBES      24.0      24.0
# 24   25        UCAYALI      25.0      25.0
#
#                                              geometry
# 0   POLYGON ((-77.81399 -2.99278, -77.81483 -2.995...
# 1   POLYGON ((-77.64697 -8.05086, -77.64689 -8.051...
# 2   POLYGON ((-73.74655 -13.17442, -73.7457 -13.17...
# 3   POLYGON ((-71.98109 -14.64062, -71.98093 -14.6...
# 4   POLYGON ((-74.34843 -12.17503, -74.35 -12.1758...
# 5   POLYGON ((-78.70034 -4.62769, -78.69817 -4.629...
# 6   POLYGON ((-77.13504 -11.8182, -77.13484 -11.81...
# 7   POLYGON ((-72.9728 -11.25189, -72.97134 -11.25...
# 8   POLYGON ((-74.57118 -11.9871, -74.57095 -11.98...
# 9   POLYGON ((-75.992 -8.32108, -75.99015 -8.32171...
# 10  POLYGON ((-75.61136 -12.96649, -75.61103 -12.9...
# 11  POLYGON ((-75.03564 -10.68232, -75.03436 -10.6...
# 12  POLYGON ((-77.75753 -6.96579, -77.75638 -6.967...
# 13  POLYGON ((-79.88373 -5.49283, -79.88265 -5.494...
# 14  MULTIPOLYGON (((-76.90483 -10.27726, -76.90451...
# 15  POLYGON ((-75.10004 -0.08096, -75.09485 -0.081...
# 16  POLYGON ((-70.61346 -10.12964, -70.61359 -10.2...
# 17  POLYGON ((-70.79388 -15.98721, -70.79486 -15.9...
# 18  POLYGON ((-74.68005 -9.44727, -74.67872 -9.448...
# 19  POLYGON ((-81.02621 -4.10594, -81.02557 -4.106...
# 20  MULTIPOLYGON (((-68.86764 -13.01075, -68.86917...
# 21  POLYGON ((-77.71678 -5.41597, -77.7127 -5.4164...
# 22  POLYGON ((-70.26604 -16.77955, -70.26474 -16.7...
# 23  POLYGON ((-80.28521 -3.41276, -80.28406 -3.412...
# 24  POLYGON ((-74.47145 -7.27617, -74.47052 -7.277...

# %%
import geopandas as gpd
from rasterstats import zonal_stats
import pandas as pd

# Ruta a shapefile procesado
shp_path = "./data/processed/departamentos.shp"

# Cargar shapefile
dept = gpd.read_file(shp_path)

# %%
# Años/bandas del ráster
anios = [2020, 2021, 2022, 2023, 2024]

# Estadísticos a calcular (incluye amplitud = max - min)
estadisticos = ["count", "mean", "min", "max", "std", "median", "percentile_10", "percentile_90", "amplitud"]

# Acumulador: por cada estadístico, una lista de arrays (uno por año)
acum = {stat: [] for stat in estadisticos}

# Loop por año (NO creamos columnas por año)
for año in anios:
    stats = zonal_stats(
        dept,
        "./data/raw/tmin_raster.tif",
        stats=["count", "mean", "min", "max", "std", "median"],   # base
        add_stats={
            "percentile_10": lambda x: np.nanpercentile(np.ma.compressed(x), 10),
            "percentile_90": lambda x: np.nanpercentile(np.ma.compressed(x), 90),
            "amplitud":      lambda x: (np.nanmax(np.ma.compressed(x)) - np.nanmin(np.ma.compressed(x))),
        },
        band=(año - 2019),  # 2020→1, 2021→2, ...
        geojson_out=False,
        nodata=None,
        all_touched=False
    )
    df = pd.DataFrame(stats)

    # Guardar vectores (uno por estadístico) para este año
    for stat in estadisticos:
        if stat in df.columns:
            acum[stat].append(df[stat].to_numpy())

# Calcular SOLO los promedios totales (2020–2024) y agregarlos a `dept`
for stat, listas in acum.items():
    if len(listas) == len(anios) and len(listas) > 0:
        # apilar años -> (n_years, n_features) y promediar por filas
        arr = np.vstack(listas)                        # shape: (5, n_deptos)
        dept[f"tmin_{stat}_total"] = np.nanmean(arr, axis=0)

# Verifica columnas creadas (solo *_total)
cols_totales = [c for c in dept.columns if c.startswith("tmin_") and c.endswith("_total")]
print("Columnas totales creadas:", cols_totales)
print(dept[["DEPARTAMEN"] + cols_totales].head())
# Out:
# Columnas totales creadas: ['tmin_count_total', 'tmin_mean_total', 'tmin_min_total', 'tmin_max_total', 'tmin_std_total', 'tmin_median_total', 'tmin_percentile_10_total', 'tmin_percentile_90_total', 'tmin_amplitud_total']
#   DEPARTAMEN  tmin_count_total  tmin_mean_total  tmin_min_total  \
# 0   AMAZONAS            1274.0        17.740650        5.449544
# 1     ANCASH            1190.0         9.204708       -0.159098
# 2   APURIMAC             711.0         4.481046       -1.854122
# 3   AREQUIPA            2124.0         6.380742       -6.064533
# 4   AYACUCHO            1454.0         5.948239       -0.877300
#
#    tmin_max_total  tmin_std_total  tmin_median_total  \
# 0       23.075594        4.362627          19.272255
# 1       18.110587        5.526664           7.963560
# 2       15.218701        3.555178           3.740294
# 3       17.383959        6.929188           8.146554
# 4       19.184651        3.946828           4.891810
#
#    tmin_percentile_10_total  tmin_percentile_90_total  tmin_amplitud_total
# 0                 10.950419                 22.493336            17.626049
# 1                  2.729118                 17.161034            18.269686
# 2                  0.578278                  9.767550            17.072824
# 3                 -2.977380                 14.398570            23.448490
# 4                  1.947629                 11.799845            20.061951

# %%
dept.head(5)
# Out:
#   CCDD DEPARTAMEN  OBJECTID  ESRI_OID  \
# 0   01   AMAZONAS       1.0       1.0
# 1   02     ANCASH       2.0       2.0
# 2   03   APURIMAC       3.0       3.0
# 3   04   AREQUIPA       4.0       4.0
# 4   05   AYACUCHO       5.0       5.0
#
#                                             geometry  tmin_count_total  \
# 0  POLYGON ((-77.81399 -2.99278, -77.81483 -2.995...            1274.0
# 1  POLYGON ((-77.64697 -8.05086, -77.64689 -8.051...            1190.0
# 2  POLYGON ((-73.74655 -13.17442, -73.7457 -13.17...             711.0
# 3  POLYGON ((-71.98109 -14.64062, -71.98093 -14.6...            2124.0
# 4  POLYGON ((-74.34843 -12.17503, -74.35 -12.1758...            1454.0
#
#    tmin_mean_total  tmin_min_total  tmin_max_total  tmin_std_total  \
# 0        17.740650        5.449544       23.075594        4.362627
# 1         9.204708       -0.159098       18.110587        5.526664
# 2         4.481046       -1.854122       15.218701        3.555178
# 3         6.380742       -6.064533       17.383959        6.929188
# 4         5.948239       -0.877300       19.184651        3.946828
#
#    tmin_median_total  tmin_percentile_10_total  tmin_percentile_90_total  \
# 0          19.272255                 10.950419                 22.493336
# 1           7.963560                  2.729118                 17.161034
# 2           3.740294                  0.578278                  9.767550
# 3           8.146554                 -2.977380                 14.398570
# 4           4.891810                  1.947629                 11.799845
#
#    tmin_amplitud_total
# 0            17.626049
# 1            18.269686
# 2            17.072824
# 3            23.448490
# 4            20.061951

# %%
resultados = []  # cada elemento será la lista de 'mean' por departamento para un año

for año in [2020, 2021, 2022, 2023, 2024]:
    stats = zonal_stats(
        dept,                               # GeoDataFrame de departamentos
        "./data/raw/tmin_raster.tif",       # ráster multibanda
        stats=["count", "mean", "min", "max", "std", "median"],
        add_stats={
            "percentile_10": lambda x: np.nanpercentile(np.ma.compressed(x), 10),
            "percentile_90": lambda x: np.nanpercentile(np.ma.compressed(x), 90),
        },
        band=(año - 2019),                  # 2020->1, 2021->2, ...
        geojson_out=False,
        nodata=None,
        all_touched=False
    )
    # ⬇️ ESTA LÍNEA DEBE ESTAR DENTRO DEL FOR
    resultados.append([s["mean"] for s in stats])

# Crear columnas por banda (o por año, si prefieres)
for i, valores in enumerate(resultados):
    dept[f"tmin_banda{i+1}"] = valores          # banda1..banda5
    # o: dept[f"tmin_{2020+i}"] = valores       # 2020..2024

# Promedio total de las 5 bandas (en 'dept', no en 'gdf')
dept["tmin_promedio_total"] = dept[[f"tmin_banda{i+1}" for i in range(5)]].mean(axis=1)
# si usaste por año: dept["tmin_promedio_total"] = dept[[f"tmin_{y}" for y in [2020,2021,2022,2023,2024]]].mean(axis=1)

# Mostrar
print(dept[["DEPARTAMEN", "tmin_promedio_total"]].head())
# Out:
#   DEPARTAMEN  tmin_promedio_total
# 0   AMAZONAS            17.740650
# 1     ANCASH             9.204708
# 2   APURIMAC             4.481046
# 3   AREQUIPA             6.380742
# 4   AYACUCHO             5.948239

# %%
dept.head(5)
# Out:
#   CCDD DEPARTAMEN  OBJECTID  ESRI_OID  \
# 0   01   AMAZONAS       1.0       1.0
# 1   02     ANCASH       2.0       2.0
# 2   03   APURIMAC       3.0       3.0
# 3   04   AREQUIPA       4.0       4.0
# 4   05   AYACUCHO       5.0       5.0
#
#                                             geometry  tmin_banda1  \
# 0  POLYGON ((-77.81399 -2.99278, -77.81483 -2.995...    17.938512
# 1  POLYGON ((-77.64697 -8.05086, -77.64689 -8.051...     9.466574
# 2  POLYGON ((-73.74655 -13.17442, -73.7457 -13.17...     4.454030
# 3  POLYGON ((-71.98109 -14.64062, -71.98093 -14.6...     6.602211
# 4  POLYGON ((-74.34843 -12.17503, -74.35 -12.1758...     5.995176
#
#    tmin_banda2  tmin_banda3  tmin_banda4  tmin_banda5  ...      20201  \
# 0    17.857031    17.694592    17.459713    17.753403  ...  17.938512
# 1     9.304433     9.168610     8.800611     9.283315  ...   9.466574
# 2     4.386174     4.549570     4.338425     4.677033  ...   4.454030
# 3     6.331513     6.365915     6.059656     6.544417  ...   6.602211
# 4     5.905022     5.993040     5.709010     6.138944  ...   5.995176
#
#        20202      20203      20204      20205  tmin_año1  tmin_año2  \
# 0  17.857031  17.694592  17.459713  17.753403  17.938512  17.857031
# 1   9.304433   9.168610   8.800611   9.283315   9.466574   9.304433
# 2   4.386174   4.549570   4.338425   4.677033   4.454030   4.386174
# 3   6.331513   6.365915   6.059656   6.544417   6.602211   6.331513
# 4   5.905022   5.993040   5.709010   6.138944   5.995176   5.905022
#
#    tmin_año3  tmin_año4  tmin_año5
# 0  17.694592  17.459713  17.753403
# 1   9.168610   8.800611   9.283315
# 2   4.549570   4.338425   4.677033
# 3   6.365915   6.059656   6.544417
# 4   5.993040   5.709010   6.138944
#
# [5 rows x 21 columns]

# %%
resultados
# Out:
# [          min        max       mean       std     median  percentile_10  \
#  0    5.607545  23.357122  17.938512  4.415945  19.482910      11.045912
#  1   -0.114301  18.689566   9.466574  5.745750   8.101915       2.795856
#  2   -1.771683  15.225024   4.454030  3.536285   3.724304       0.559477
#  3   -5.922765  17.838457   6.602211  6.992906   8.379168      -2.805674
#  4   -0.792948  19.389566   5.995176  3.949300   4.907458       2.020190
#  5    4.604817  21.459833  12.896788  4.172748  12.991574       6.976535
#  6   17.608805  18.408934  17.863834  0.281944  17.779911      17.645927
#  7   -6.198120  22.636209   9.019368  8.263553   7.660058      -0.891095
#  8   -1.698617  15.772893   3.822584  3.952307   2.842624      -0.556065
#  9    0.268243  22.860834  13.378673  6.668933  13.174327       4.787189
#  10   0.146446  17.855211  14.108443  2.423862  14.666621      11.491340
#  11  -1.744987  22.591087  10.228214  7.749270  10.191409       0.585798
#  12   4.141730  19.794155  13.177351  5.157643  13.635919       6.030973
#  13   6.830308  20.222134  18.772242  2.211836  19.356434      18.017614
#  14  -1.604495  18.825569   9.798001  6.657849  10.814537       0.643698
#  15  14.655350  23.911810  22.692363  0.736786  22.825262      22.395199
#  16   5.169679  22.856165  21.802522  1.630788  22.124838      21.501587
#  17  -6.549748  18.044506   5.119515  7.537224   5.836290      -4.952360
#  18   0.297934  22.260225  13.953690  7.410199  17.309002       2.297132
#  19   8.524505  21.938833  19.062647  2.883127  20.277891      14.035987
#  20  -8.722504  22.712975   3.078459  8.340207  -0.233264      -3.795721
#  21   4.687482  22.998430  17.765007  4.186223  19.015694      11.224953
#  22  -8.782926  17.807444   7.356924  8.328425  11.539501      -5.814489
#  23  18.090879  22.982765  21.702047  0.958555  21.989676      20.228964
#  24  14.998993  23.220053  22.020845  1.076300  22.264555      21.844372
#
#      percentile_90   AÑO   DEPARTAMENTO
#  0       22.771120  2020       AMAZONAS
#  1       17.856094  2020         ANCASH
#  2        9.713305  2020       APURIMAC
#  3       14.752823  2020       AREQUIPA
#  4       11.851123  2020       AYACUCHO
#  5       18.383768  2020      CAJAMARCA
#  6       18.173325  2020         CALLAO
#  7       21.317759  2020          CUSCO
#  8        9.898214  2020   HUANCAVELICA
#  9       22.312134  2020        HUANUCO
#  10      16.087982  2020            ICA
#  11      20.143835  2020          JUNIN
#  12      18.881884  2020    LA LIBERTAD
#  13      19.855997  2020     LAMBAYEQUE
#  14      17.355167  2020           LIMA
#  15      23.125555  2020         LORETO
#  16      22.593769  2020  MADRE DE DIOS
#  17      13.884339  2020       MOQUEGUA
#  18      21.689653  2020          PASCO
#  19      21.050837  2020          PIURA
#  20      18.898897  2020           PUNO
#  21      22.002823  2020     SAN MARTIN
#  22      15.742857  2020          TACNA
#  23      22.662060  2020         TUMBES
#  24      22.584785  2020        UCAYALI  ,
#            min        max       mean       std     median  percentile_10  \
#  0    5.371010  23.256083  17.857031  4.433787  19.438667      10.942151
#  1   -0.279024  18.306875   9.304433  5.589794   8.052099       2.748828
#  2   -2.095827  15.282331   4.386174  3.610984   3.646188       0.420034
#  3   -6.683664  17.588608   6.331513  7.157116   8.153635      -3.370600
#  4   -1.078459  19.316561   5.905022  4.040536   4.850075       1.788551
#  5    4.224303  21.549995  12.704185  4.244364  12.836368       6.693088
#  6   17.041285  18.067162  17.382516  0.361428  17.326342      17.076912
#  7   -6.479555  22.611977   8.859186  8.358581   7.610305      -1.307983
#  8   -2.174469  15.728219   3.567350  4.070073   2.543436      -0.937138
#  9    0.435766  22.563538  13.381851  6.545255  13.220856       4.986488
#  10  -0.092868  17.713255  13.885537  2.370149  14.377040      11.518369
#  11  -2.041530  22.537329  10.024486  7.864735  10.068441       0.212052
#  12   3.934917  19.758638  12.802789  4.999260  13.470792       5.803444
#  13   6.499071  19.673880  18.149590  2.128268  18.692513      17.556768
#  14  -2.096419  18.524752   9.637440  6.596606  10.815018       0.449198
#  15  14.647891  23.930971  22.682117  0.746897  22.827963      22.336164
#  16   5.218569  22.840559  21.756950  1.642816  22.089800      21.430756
#  17  -7.424730  17.813829   4.780878  7.613369   5.458536      -5.432208
#  18   0.159167  22.124847  13.851471  7.389283  17.218708       2.207119
#  19   8.265311  21.641691  18.527937  2.757923  19.595320      13.796665
#  20  -9.938132  22.666143   2.817761  8.411048  -0.508553      -4.129482
#  21   4.468945  22.982111  17.730184  4.225451  18.969204      11.059023
#  22 -10.024566  17.428507   6.879675  8.433713  11.187561      -6.416869
#  23  17.879477  23.019821  21.547717  0.975437  21.833607      20.133659
#  24  15.057304  23.151848  21.956080  1.074426  22.204893      21.784887
#
#      percentile_90   AÑO   DEPARTAMENTO
#  0       22.668276  2021       AMAZONAS
#  1       17.315981  2021         ANCASH
#  2        9.726325  2021       APURIMAC
#  3       14.600312  2021       AREQUIPA
#  4       11.914505  2021       AYACUCHO
#  5       18.252394  2021      CAJAMARCA
#  6       17.779276  2021         CALLAO
#  7       21.231430  2021          CUSCO
#  8        9.818113  2021   HUANCAVELICA
#  9       22.144651  2021        HUANUCO
#  10      15.823440  2021            ICA
#  11      20.070580  2021          JUNIN
#  12      18.258617  2021    LA LIBERTAD
#  13      19.208136  2021     LAMBAYEQUE
#  14      16.927935  2021           LIMA
#  15      23.138254  2021         LORETO
#  16      22.554552  2021  MADRE DE DIOS
#  17      13.635717  2021       MOQUEGUA
#  18      21.545448  2021          PASCO
#  19      20.490629  2021          PIURA
#  20      18.716953  2021           PUNO
#  21      21.892969  2021     SAN MARTIN
#  22      15.397240  2021          TACNA
#  23      22.542753  2021         TUMBES
#  24      22.510246  2021        UCAYALI  ,
#            min        max       mean       std     median  percentile_10  \
#  0    5.344406  23.092096  17.694592  4.399574  19.202652      10.835829
#  1   -0.199922  18.153667   9.168610  5.559724   7.941746       2.635011
#  2   -1.924250  15.438622   4.549570  3.619952   3.800889       0.580437
#  3   -5.804063  17.521782   6.365915  6.948725   8.081802      -2.973691
#  4   -0.974195  19.367870   5.993040  4.006882   4.953797       1.929858
#  5    4.325144  21.433317  12.568275  4.180074  12.592620       6.615661
#  6   16.970484  18.009005  17.326057  0.359643  17.269457      17.025089
#  7   -6.027426  22.462412   9.096250  8.193932   7.780009      -0.828465
#  8   -1.778522  15.779938   3.751320  3.981618   2.744298      -0.612952
#  9    0.330092  22.599394  13.397104  6.546976  13.234578       5.019230
#  10   0.074993  17.506647  13.923106  2.349832  14.466594      11.548852
#  11  -1.828417  22.428085  10.175113  7.769533  10.176950       0.476997
#  12   3.736957  19.634249  12.664774  4.987395  13.345757       5.666763
#  13   6.307388  19.440962  17.918109  2.109710  18.464760      17.351738
#  14  -1.679661  18.358068   9.544372  6.516282  10.731674       0.550059
#  15  14.491039  23.740320  22.392380  0.717503  22.522028      22.138069
#  16   5.319707  22.823366  21.685962  1.594924  21.981745      21.407713
#  17  -7.134834  17.799852   4.813531  7.529471   5.372817      -5.245722
#  18   0.149587  22.116362  13.899161  7.372839  17.203365       2.285858
#  19   8.027003  21.370905  18.267236  2.741424  19.285040      13.569448
#  20  -9.663869  22.601685   3.077386  8.333905  -0.177597      -3.756665
#  21   4.438656  22.907473  17.611790  4.212179  18.876656      11.009960
#  22  -9.866587  17.376577   6.912490  8.277785  11.239895      -6.138583
#  23  17.467478  22.612726  21.181376  0.993806  21.456726      19.668346
#  24  14.875388  23.097122  21.817680  1.054477  22.043709      21.647869
#
#      percentile_90   AÑO   DEPARTAMENTO
#  0       22.495073  2022       AMAZONAS
#  1       17.150188  2022         ANCASH
#  2        9.963527  2022       APURIMAC
#  3       14.425317  2022       AREQUIPA
#  4       11.899721  2022       AYACUCHO
#  5       18.020964  2022      CAJAMARCA
#  6       17.715139  2022         CALLAO
#  7       21.222519  2022          CUSCO
#  8        9.916910  2022   HUANCAVELICA
#  9       22.148306  2022        HUANUCO
#  10      15.798523  2022            ICA
#  11      20.095663  2022          JUNIN
#  12      18.093447  2022    LA LIBERTAD
#  13      18.944105  2022     LAMBAYEQUE
#  14      16.765383  2022           LIMA
#  15      22.821768  2022         LORETO
#  16      22.483831  2022  MADRE DE DIOS
#  17      13.584832  2022       MOQUEGUA
#  18      21.595638  2022          PASCO
#  19      20.233730  2022          PIURA
#  20      18.854298  2022           PUNO
#  21      21.824997  2022     SAN MARTIN
#  22      15.273779  2022          TACNA
#  23      22.164778  2022         TUMBES
#  24      22.360838  2022        UCAYALI  ,
#            min        max       mean       std     median  percentile_10  \
#  0    5.277322  22.686312  17.459713  4.270094  18.945972      10.842900
#  1   -0.366369  17.475357   8.800611  5.388094   7.608573       2.502638
#  2   -1.935384  14.954243   4.338425  3.520133   3.577447       0.495251
#  3   -6.126846  17.023081   6.059656  6.818554   7.789589      -3.145681
#  4   -0.991162  18.824888   5.709010  3.875945   4.651391       1.787735
#  5    4.142351  21.118492  12.272801  4.102017  12.314433       6.400005
#  6   16.261812  17.172255  16.584097  0.314188  16.546621      16.308950
#  7   -6.045058  22.060377   8.834165  8.077129   7.539042      -0.953914
#  8   -1.953125  15.320042   3.545273  3.931615   2.604468      -0.808830
#  9    0.219690  22.163397  13.044991  6.460785  12.881629       4.749863
#  10  -0.108187  16.850882  13.432805  2.270011  13.930200      11.237042
#  11  -2.111839  22.006742   9.831402  7.713364   9.910312       0.174140
#  12   3.492925  19.039606  12.113711  4.740840  12.863114       5.456767
#  13   6.217253  18.850323  17.434201  2.048545  17.979868      16.756140
#  14  -1.933315  17.549431   9.067315  6.338406  10.188321       0.263956
#  15  14.253089  23.358114  22.197654  0.760166  22.317762      21.765926
#  16   5.221374  22.427986  21.374805  1.590529  21.693319      21.054903
#  17  -6.429159  17.585596   4.805331  7.345367   5.280319      -4.942687
#  18   0.011164  21.634247  13.542042  7.281508  16.859026       2.081154
#  19   7.972269  20.858847  17.842958  2.638690  18.850897      13.326904
#  20  -8.105174  22.286303   3.023144  8.156753  -0.244747      -3.655005
#  21   4.364245  22.627533  17.367988  4.151103  18.645302      10.805173
#  22  -8.147947  17.264048   6.990777  8.048130  11.014317      -5.798337
#  23  17.148504  22.327919  20.776989  0.963257  21.011696      19.360689
#  24  14.632594  22.641493  21.457449  1.042941  21.703804      21.305735
#
#      percentile_90   AÑO   DEPARTAMENTO
#  0       22.112890  2023       AMAZONAS
#  1       16.581795  2023         ANCASH
#  2        9.598248  2023       APURIMAC
#  3       13.938919  2023       AREQUIPA
#  4       11.450027  2023       AYACUCHO
#  5       17.500816  2023      CAJAMARCA
#  6       16.927410  2023         CALLAO
#  7       20.779943  2023          CUSCO
#  8        9.571636  2023   HUANCAVELICA
#  9       21.682169  2023        HUANUCO
#  10      15.259738  2023            ICA
#  11      19.665831  2023          JUNIN
#  12      17.196997  2023    LA LIBERTAD
#  13      18.500580  2023     LAMBAYEQUE
#  14      16.108618  2023           LIMA
#  15      22.765947  2023         LORETO
#  16      22.153013  2023  MADRE DE DIOS
#  17      13.340832  2023       MOQUEGUA
#  18      21.105907  2023          PASCO
#  19      19.739237  2023          PIURA
#  20      18.513939  2023           PUNO
#  21      21.494947  2023     SAN MARTIN
#  22      15.182106  2023          TACNA
#  23      21.737999  2023         TUMBES
#  24      21.966969  2023        UCAYALI  ,
#            min        max       mean       std     median  percentile_10  \
#  0    5.647437  22.986359  17.753403  4.293738  19.291071      11.085308
#  1    0.164126  17.927471   9.283315  5.349958   8.113466       2.963256
#  2   -1.543467  15.193284   4.677033  3.488534   3.952644       0.836191
#  3   -5.785328  16.947866   6.544417  6.728639   8.328574      -2.591252
#  4   -0.549739  19.024370   6.138944  3.861475   5.096327       2.211810
#  5    4.678347  21.316931  12.703393  4.070149  12.761579       6.986324
#  6   16.628218  17.450464  16.913010  0.290783  16.870129      16.652039
#  7   -5.752409  22.343264   9.062771  8.059982   7.817102      -0.632849
#  8   -1.496443  15.564656   3.973137  3.891151   3.020215      -0.366669
#  9    0.686670  22.625916  13.374472  6.491727  13.172187       5.066082
#  10   0.432037  17.174116  13.743344  2.200324  14.180511      11.678184
#  11  -1.657722  22.279930  10.118613  7.691624  10.219558       0.415894
#  12   4.233429  19.489336  12.689975  4.703924  13.503075       6.073997
#  13   6.779275  19.315716  17.852770  2.016650  18.379110      17.191849
#  14  -1.579841  17.810953   9.619457  6.323676  10.811464       0.786070
#  15  14.644642  23.635798  22.427863  0.723203  22.553459      22.090048
#  16   5.520821  22.578951  21.535102  1.583117  21.856081      21.233860
#  17  -6.169868  17.345266   5.014100  7.255278   5.626857      -4.735203
#  18   0.413027  22.029116  13.862200  7.284429  17.207191       2.406175
#  19   8.468678  21.245708  18.234837  2.614759  19.195864      13.745353
#  20  -7.580888  22.419680   3.137031  8.149383  -0.145767      -3.483628
#  21   4.778517  22.742966  17.641725  4.104404  18.867062      11.153820
#  22  -7.479485  16.950039   7.051213  7.808717  11.144931      -5.394721
#  23  17.664610  22.709639  21.197782  0.949349  21.441669      19.823084
#  24  15.034389  22.967215  21.740667  1.028033  21.970530      21.562637
#
#      percentile_90   AÑO   DEPARTAMENTO
#  0       22.419319  2024       AMAZONAS
#  1       16.901114  2024         ANCASH
#  2        9.836348  2024       APURIMAC
#  3       14.275484  2024       AREQUIPA
#  4       11.883846  2024       AYACUCHO
#  5       17.950544  2024      CAJAMARCA
#  6       17.241663  2024         CALLAO
#  7       20.990885  2024          CUSCO
#  8       10.025224  2024   HUANCAVELICA
#  9       22.136120  2024        HUANUCO
#  10      15.515084  2024            ICA
#  11      19.904814  2024          JUNIN
#  12      17.751984  2024    LA LIBERTAD
#  13      18.868048  2024     LAMBAYEQUE
#  14      16.552065  2024           LIMA
#  15      22.907396  2024         LORETO
#  16      22.302462  2024  MADRE DE DIOS
#  17      13.486762  2024       MOQUEGUA
#  18      21.394211  2024          PASCO
#  19      20.114649  2024          PIURA
#  20      18.633411  2024           PUNO
#  21      21.759087  2024     SAN MARTIN
#  22      14.923881  2024          TACNA
#  23      22.183020  2024         TUMBES
#  24      22.286232  2024        UCAYALI  ]

# %%
# Combinar todos los resultados
tmin_dept = pd.concat(resultados)
tmin_dept.reset_index(drop=True, inplace=True)

# %%
print("Estadísticas zonales calculadas correctamente")
tmin_dept.head()
# Out:
# Estadísticas zonales calculadas correctamente
#         min        max       mean       std     median  percentile_10  \
# 0  5.607545  23.357122  17.938512  4.415945  19.482910      11.045912
# 1 -0.114301  18.689566   9.466574  5.745750   8.101915       2.795856
# 2 -1.771683  15.225024   4.454030  3.536285   3.724304       0.559477
# 3 -5.922765  17.838457   6.602211  6.992906   8.379168      -2.805674
# 4 -0.792948  19.389566   5.995176  3.949300   4.907458       2.020190
#
#    percentile_90   AÑO DEPARTAMENTO
# 0      22.771120  2020     AMAZONAS
# 1      17.856094  2020       ANCASH
# 2       9.713305  2020     APURIMAC
# 3      14.752823  2020     AREQUIPA
# 4      11.851123  2020     AYACUCHO

# %%
import geopandas as gpd
from rasterstats import zonal_stats
import pandas as pd

# Ruta a shapefile procesado
shp_path = "../data/processed/departamentos.shp"

# Cargar shapefile
dept = gpd.read_file(shp_path)

# Calcular estadísticas zonales por año
resultados = []

for año in [2020, 2021, 2022, 2023, 2024]:
    stats = zonal_stats(
        dept,
        f"../data/raw/tmin_raster.tif",
        stats=["mean", "min", "max", "std", "median", "percentile_10", "percentile_90"],
        band=[año - 2019],  # banda 1=2020, etc.
        geojson_out=False,
        nodata=None
    )
    
    df_stats = pd.DataFrame(stats)
    df_stats["AÑO"] = año
    df_stats["DEPARTAMENTO"] = dept["DEPARTAMEN"].values
    resultados.append(df_stats)

# Combinar todos los resultados
tmin_dept = pd.concat(resultados)
tmin_dept.reset_index(drop=True, inplace=True)

print("Estadísticas zonales calculadas correctamente")
tmin_dept.head()
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In[41], line 9
#       6 shp_path = "../data/processed/departamentos.shp"
#       8 # Cargar shapefile
# ----> 9 dept = gpd.read_file(shp_path)
#      11 # Calcular estadísticas zonales por año
#      12 resultados = []
#
# File ~/anaconda3/envs/raster1/lib/python3.11/site-packages/geopandas/io/file.py:316, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     313             filename = response.read()
#     315 if engine == "pyogrio":
# --> 316     return _read_file_pyogrio(
#     317         filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     318     )
#     320 elif engine == "fiona":
#     321     if pd.api.types.is_file_like(filename):
#
# File ~/anaconda3/envs/raster1/lib/python3.11/site-packages/geopandas/io/file.py:576, in _read_file_pyogrio(path_or_bytes, bbox, mask, rows, **kwargs)
#     567     warnings.warn(
#     568         "The 'include_fields' and 'ignore_fields' keywords are deprecated, and "
#     569         "will be removed in a future release. You can use the 'columns' keyword "
#    (...)    572         stacklevel=3,
#     573     )
#     574     kwargs["columns"] = kwargs.pop("include_fields")
# --> 576 return pyogrio.read_dataframe(path_or_bytes, bbox=bbox, **kwargs)
#
# File ~/anaconda3/envs/raster1/lib/python3.11/site-packages/pyogrio/geopandas.py:275, in read_dataframe(path_or_buffer, layer, encoding, columns, read_geometry, force_2d, skip_features, max_features, where, bbox, mask, fids, sql, sql_dialect, fid_as_index, use_arrow, on_invalid, arrow_to_pandas_kwargs, **kwargs)
#     270 if not use_arrow:
#     271     # For arrow, datetimes are read as is.
#     272     # For numpy IO, datetimes are read as string values to preserve timezone info
#     273     # as numpy does not directly support timezones.
#     274     kwargs["datetime_as_string"] = True
# --> 275 result = read_func(
#     276     path_or_buffer,
#     277     layer=layer,
#     278     encoding=encoding,
#     279     columns=columns,
#     280     read_geometry=read_geometry,
#     281     force_2d=gdal_force_2d,
#     282     skip_features=skip_features,
#     283     max_features=max_features,
#     284     where=where,
#     285     bbox=bbox,
#     286     mask=mask,
#     287     fids=fids,
#     288     sql=sql,
#     289     sql_dialect=sql_dialect,
#     290     return_fids=fid_as_index,
#     291     **kwargs,
#     292 )
#     294 if use_arrow:
#     295     import pyarrow as pa
#
# File ~/anaconda3/envs/raster1/lib/python3.11/site-packages/pyogrio/raw.py:198, in read(path_or_buffer, layer, encoding, columns, read_geometry, force_2d, skip_features, max_features, where, bbox, mask, fids, sql, sql_dialect, return_fids, datetime_as_string, **kwargs)
#      59 """Read OGR data source into numpy arrays.
#      60
#      61 IMPORTANT: non-linear geometry types (e.g., MultiSurface) are converted
#    (...)    194
#     195 """
#     196 dataset_kwargs = _preprocess_options_key_value(kwargs) if kwargs else {}
# --> 198 return ogr_read(
#     199     get_vsi_path_or_buffer(path_or_buffer),
#     200     layer=layer,
#     201     encoding=encoding,
#     202     columns=columns,
#     203     read_geometry=read_geometry,
#     204     force_2d=force_2d,
#     205     skip_features=skip_features,
#     206     max_features=max_features or 0,
#     207     where=where,
#     208     bbox=bbox,
#     209     mask=_mask_to_wkb(mask),
#     210     fids=fids,
#     211     sql=sql,
#     212     sql_dialect=sql_dialect,
#     213     return_fids=return_fids,
#     214     dataset_kwargs=dataset_kwargs,
#     215     datetime_as_string=datetime_as_string,
#     216 )
#
# File pyogrio/_io.pyx:1293, in pyogrio._io.ogr_read()
#
# File pyogrio/_io.pyx:232, in pyogrio._io.ogr_open()
#
# DataSourceError: ../data/processed/departamentos.shp: No such file or directory

# %%
dist
# Out:
#       UBIGEO CCDD CCPP CCDI DEPARTAMEN    PROVINCIA                DISTRITO  \
# 0     010101   01   01   01   AMAZONAS  CHACHAPOYAS             CHACHAPOYAS
# 1     010102   01   01   02   AMAZONAS  CHACHAPOYAS                ASUNCION
# 2     010103   01   01   03   AMAZONAS  CHACHAPOYAS                  BALSAS
# 3     010104   01   01   04   AMAZONAS  CHACHAPOYAS                   CHETO
# 4     010105   01   01   05   AMAZONAS  CHACHAPOYAS               CHILIQUIN
# ...      ...  ...  ...  ...        ...          ...                     ...
# 1886  250304   25   03   04    UCAYALI   PADRE ABAD                 NESHUYA
# 1887  250305   25   03   05    UCAYALI   PADRE ABAD  ALEXANDER VON HUMBOLDT
# 1888  250306   25   03   06    UCAYALI   PADRE ABAD                 HUIPOCA
# 1889  250307   25   03   07    UCAYALI   PADRE ABAD                BOQUERON
# 1890  250401   25   04   01    UCAYALI        PURUS                   PURUS
#
#       OBJECTID  ESRI_OID                                           GEOMETRY
# 0          1.0       1.0  POLYGON ((-77.8858 -6.1778, -77.88323 -6.17846...
# 1          2.0       2.0  POLYGON ((-77.74482 -5.94497, -77.74482 -5.945...
# 2          3.0       3.0  POLYGON ((-77.9358 -6.69039, -77.93531 -6.6909...
# 3          4.0       4.0  POLYGON ((-77.71486 -6.24598, -77.71485 -6.245...
# 4          5.0       5.0  POLYGON ((-77.77405 -5.99598, -77.77328 -5.996...
# ...        ...       ...                                                ...
# 1886    1887.0    1887.0  POLYGON ((-75.01663 -8.44514, -75.0165 -8.4453...
# 1887    1888.0    1888.0  POLYGON ((-75.02136 -8.73948, -75.02136 -8.739...
# 1888    1889.0    1889.0  POLYGON ((-75.3844 -8.58229, -75.38423 -8.5825...
# 1889    1890.0    1890.0  POLYGON ((-75.77583 -8.91013, -75.77427 -8.910...
# 1890    1891.0    1891.0  POLYGON ((-70.50641 -9.42392, -70.50643 -9.424...
#
# [1891 rows x 10 columns]

# %% [markdown]
#  ## Recorte del ráster completo (las 5 bandas) a Perú usando los distritos

# %%
tmin
# Out:
# <xarray.DataArray (band: 5, y: 397, x: 285)> Size: 2MB
# [565725 values with dtype=float32]
# Coordinates:
#   * band         (band) int64 40B 2020 2021 2022 2023 2024
#   * y            (y) float64 3kB 1.175 1.125 1.075 ... -18.53 -18.58 -18.63
#   * x            (x) float64 2kB -81.35 -81.3 -81.25 ... -67.26 -67.21 -67.16
#     spatial_ref  int64 8B 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0

# %%
from rasterio.mask import mask

# Abrir y recortar todas las bandas del ráster
with rasterio.open("raster_path") as src:
    out_image, out_transform = mask(src, dist.geometry, crop=True)
    out_meta = src.meta.copy()
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File rasterio/_base.pyx:310, in rasterio._base.DatasetBase.__init__()
#
# File rasterio/_base.pyx:221, in rasterio._base.open_dataset()
#
# File rasterio/_err.pyx:359, in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: raster_path: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# Cell In[44], line 4
#       1 from rasterio.mask import mask
#       3 # Abrir y recortar todas las bandas del ráster
# ----> 4 with rasterio.open("raster_path") as src:
#       5     out_image, out_transform = mask(src, dist.geometry, crop=True)
#       6     out_meta = src.meta.copy()
#
# File ~/anaconda3/envs/raster1/lib/python3.11/site-packages/rasterio/env.py:463, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     460     session = DummySession()
#     462 with env_ctor(session=session):
# --> 463     return f(*args, **kwds)
#
# File ~/anaconda3/envs/raster1/lib/python3.11/site-packages/rasterio/__init__.py:356, in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, opener, **kwargs)
#     353     path = _parse_path(raw_dataset_path)
#     355 if mode == "r":
# --> 356     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     357 elif mode == "r+":
#     358     dataset = get_writer_for_path(path, driver=driver)(
#     359         path, mode, driver=driver, sharing=sharing, **kwargs
#     360     )
#
# File rasterio/_base.pyx:312, in rasterio._base.DatasetBase.__init__()
#
# RasterioIOError: raster_path: No such file or directory

# %%
from rasterio.mask import mask

# Abrir y recortar todas las bandas del ráster
with rasterio.open("tmin") as src:
    out_image, out_transform = mask(src, dist.geometry, crop=True)
    out_meta = src.meta.copy()

out_meta.update({
    "driver": "GTiff",
    "height": out_image.shape[1],
    "width": out_image.shape[2],
    "transform": out_transform
})

# Guardar el nuevo ráster recortado
with rasterio.open("tmin_raster_dist.tif", "w", **out_meta) as dest:
    dest.write(out_image)
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File rasterio/_base.pyx:310, in rasterio._base.DatasetBase.__init__()
#
# File rasterio/_base.pyx:221, in rasterio._base.open_dataset()
#
# File rasterio/_err.pyx:359, in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: tmin: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# Cell In[40], line 4
#       1 from rasterio.mask import mask
#       3 # Abrir y recortar todas las bandas del ráster
# ----> 4 with rasterio.open("tmin") as src:
#       5     out_image, out_transform = mask(src, dist.geometry, crop=True)
#       6     out_meta = src.meta.copy()
#
# File ~/anaconda3/envs/raster1/lib/python3.11/site-packages/rasterio/env.py:463, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     460     session = DummySession()
#     462 with env_ctor(session=session):
# --> 463     return f(*args, **kwds)
#
# File ~/anaconda3/envs/raster1/lib/python3.11/site-packages/rasterio/__init__.py:356, in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, opener, **kwargs)
#     353     path = _parse_path(raw_dataset_path)
#     355 if mode == "r":
# --> 356     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     357 elif mode == "r+":
#     358     dataset = get_writer_for_path(path, driver=driver)(
#     359         path, mode, driver=driver, sharing=sharing, **kwargs
#     360     )
#
# File rasterio/_base.pyx:312, in rasterio._base.DatasetBase.__init__()
#
# RasterioIOError: tmin: No such file or directory
